# %% [markdown]
# <a href="https://colab.research.google.com/github/Baraa710/Premier_League_Predictor/blob/main/systematicHyperparameterSelection4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# winner
#
# home wins
#
# away wins
#
# home games
#
# away games
#
# predicted_winner
#
# Player_home_player_2
#
# Age_home_player_2
#
# MP_home_player_2
#
# Min_home_player_2
#
# Gls_home_player_2
#
# Ast_home_player_2
#
# PK_home_player_2
#
# PKatt_home_player_2
#
# CrdY_home_player_2
#
# CrdR_home_player_2
#
# Starts_home_player_2
#
# Player_home_player_3
#
# Age_home_player_3
#
# MP_home_player_3
#
# Min_home_player_3
#
# Gls_home_player_3
#
# Ast_home_player_3
#
# PK_home_player_3
#
# PKatt_home_player_3
#
# CrdY_home_player_3
#
# CrdR_home_player_3
#
# Starts_home_player_3
#
# Player_home_player_4
#
# Age_home_player_4
#
# MP_home_player_4
#
# Min_home_player_4
#
# Gls_home_player_4
#
# Ast_home_player_4
#
# PK_home_player_4
#
# PKatt_home_player_4
#
# CrdY_home_player_4
#
# CrdR_home_player_4
#
# Starts_home_player_4
#
# Player_home_player_5
#
# Age_home_player_5
#
# MP_home_player_5
#
# Min_home_player_5
#
# Gls_home_player_5
#
# Ast_home_player_5
#
# PK_home_player_5
#
# PKatt_home_player_5
#
# CrdY_home_player_5
#
# CrdR_home_player_5
#
# Starts_home_player_5
#
# Player_home_player_6
#
# Age_home_player_6
#
# MP_home_player_6
#
# Min_home_player_6
#
# Gls_home_player_6
#
# Ast_home_player_6
#
# PK_home_player_6
#
# PKatt_home_player_6
#
# CrdY_home_player_6
#
# CrdR_home_player_6
#
# Starts_home_player_6
#
# Player_home_player_7
#
# Age_home_player_7
#
# MP_home_player_7
#
# Min_home_player_7
#
# Gls_home_player_7
#
# Ast_home_player_7
#
# PK_home_player_7
#
# PKatt_home_player_7
#
# CrdY_home_player_7
#
# CrdR_home_player_7
#
# Starts_home_player_7
#
# Player_home_player_8
#
# Age_home_player_8
#
# MP_home_player_8
#
# Min_home_player_8
#
# Gls_home_player_8
#
# Ast_home_player_8
#
# PK_home_player_8
#
# PKatt_home_player_8
#
# CrdY_home_player_8
#
# CrdR_home_player_8
#
# Starts_home_player_8
#
# Player_home_player_9
#
# Age_home_player_9
#
# MP_home_player_9
#
# Min_home_player_9
#
# Gls_home_player_9
#
# Ast_home_player_9
#
# PK_home_player_9
#
# PKatt_home_player_9
#
# CrdY_home_player_9
#
# CrdR_home_player_9
#
# Starts_home_player_9
#
# Player_home_player_10
#
# Age_home_player_10
#
# MP_home_player_10
#
# Min_home_player_10
#
# Gls_home_player_10
#
# Ast_home_player_10
#
# PK_home_player_10
#
# PKatt_home_player_10
#
# CrdY_home_player_10
#
# CrdR_home_player_10
#
# Starts_home_player_10
#
# Player_home_player_11
#
# Age_home_player_11
#
# MP_home_player_11
#
# Min_home_player_11
#
# Gls_home_player_11
#
# Ast_home_player_11
#
# PK_home_player_11
#
# PKatt_home_player_11
#
# CrdY_home_player_11
#
# CrdR_home_player_11
#
# Starts_home_player_11
#
# Player_away_player_2
#
# Age_away_player_2
#
# MP_away_player_2
#
# Min_away_player_2
#
# Gls_away_player_2
#
# Ast_away_player_2
#
# PK_away_player_2
#
# PKatt_away_player_2
#
# CrdY_away_player_2
#
# CrdR_away_player_2
#
# Starts_away_player_2
#
# Player_away_player_3
#
# Age_away_player_3
#
# MP_away_player_3
#
# Min_away_player_3
#
# Gls_away_player_3
#
# Ast_away_player_3
#
# PK_away_player_3
#
# PKatt_away_player_3
#
# CrdY_away_player_3
#
# CrdR_away_player_3
#
# Starts_away_player_3
#
# Player_away_player_4
#
# Age_away_player_4
#
# MP_away_player_4
#
# Min_away_player_4
#
# Gls_away_player_4
#
# Ast_away_player_4
#
# PK_away_player_4
#
# PKatt_away_player_4
#
# CrdY_away_player_4
#
# CrdR_away_player_4
#
# Starts_away_player_4
#
# Player_away_player_5
#
# Age_away_player_5
#
# MP_away_player_5
#
# Min_away_player_5
#
# Gls_away_player_5
#
# Ast_away_player_5
#
# PK_away_player_5
#
# PKatt_away_player_5
#
# CrdY_away_player_5
#
# CrdR_away_player_5
#
# Starts_away_player_5
#
# Player_away_player_6
#
# Age_away_player_6
#
# MP_away_player_6
#
# Min_away_player_6
#
# Gls_away_player_6
#
# Ast_away_player_6
#
# PK_away_player_6
#
# PKatt_away_player_6
#
# CrdY_away_player_6
#
# CrdR_away_player_6
#
# Starts_away_player_6
#
# Player_away_player_7
#
# Age_away_player_7
#
# MP_away_player_7
#
# Min_away_player_7
#
# Gls_away_player_7
#
# Ast_away_player_7
#
# PK_away_player_7
#
# PKatt_away_player_7
#
# CrdY_away_player_7
#
# CrdR_away_player_7
#
# Starts_away_player_7
#
# Player_away_player_8
#
# Age_away_player_8
#
# MP_away_player_8
#
# Min_away_player_8
#
# Gls_away_player_8
#
# Ast_away_player_8
#
# PK_away_player_8
#
# PKatt_away_player_8
#
# CrdY_away_player_8
#
# CrdR_away_player_8
#
# Starts_away_player_8
#
# Player_away_player_9
#
# Age_away_player_9
#
# MP_away_player_9
#
# Min_away_player_9
#
# Gls_away_player_9
#
# Ast_away_player_9
#
# PK_away_player_9
#
# PKatt_away_player_9
#
# CrdY_away_player_9
#
# CrdR_away_player_9
#
# Starts_away_player_9
#
# Player_away_player_10
#
# Age_away_player_10
#
# MP_away_player_10
#
# Min_away_player_10
#
# Gls_away_player_10
#
# Ast_away_player_10
#
# PK_away_player_10
#
# PKatt_away_player_10
#
# CrdY_away_player_10
#
# CrdR_away_player_10
#
# Starts_away_player_10
#
# Player_away_player_11
#
# Age_away_player_11
#
# MP_away_player_11
#
# Min_away_player_11
#
# Gls_away_player_11
#
# Ast_away_player_11
#
# PK_away_player_11
#
# PKatt_away_player_11
#
# CrdY_away_player_11
#
# CrdR_away_player_11
#
# Starts_away_player_11
#
# Rk_home
#
# Squad_home
#
# MP_home
#
# W_home
#
# D_home
#
# L_home
#
# Pts_home
#
# Pts/MP_home
#
# Pl_home
#
# Gls_home
#
# Ast_home
#
# PK_home
#
# PKatt_home
#
# CrdY_home
#
# CrdR_home
#
# GA_home
#
# SoTA_home
#
# Saves_home
#
# CS_home
#
# SoT_home
#
# PremierLeague_home
#
# Rk_away
#
# Squad_away
#
# MP_away
#
# W_away
#
# D_away
#
# L_away
#
# Pts_away
#
# Pts/MP_away
#
# # Pl_away
#
# Gls_away
#
# Ast_away
#
# PK_away
#
# PKatt_away
#
# CrdY_away
#
# CrdR_away
#
# GA_away
#
# SoTA_away
#
# Saves_away
#
# CS_away
#
# SoT_away
#
# PremierLeague_away

# %% [markdown]
# # DATA SPLITTING

# %%
import pandas as pd
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import matplotlib.pyplot as plt
from torch.utils.data import TensorDataset, DataLoader
from sklearn.preprocessing import MinMaxScaler

# %%
# Read the Excel file
df = pd.read_excel("/content/drive/MyDrive/APS360_Project/Match_Data/total_match_data_4.xlsx")

# %%
df.dropna(inplace=True)
pd.set_option('display.max_columns', None)
df
# Out:
#       Unnamed: 0  Wk  winner  home wins  away wins  home games  away games  \
# 380            0   1       1          0          0           0           0
# 381            1   1       0          0          0           0           0
# 382            2   1       1          0          0           0           0
# 383            3   1       1          0          0           0           0
# 384            4   1       1          0          0           0           0
# ...          ...  ..     ...        ...        ...         ...         ...
# 6453         374  38       2          6         19          37          37
# 6454         375  38       0          7         11          37          37
# 6455         376  38       0          8         11          37          37
# 6456         377  38       0         17         18          37          37
# 6458         379  38       0         14         28          37          37
#
#       predicted_winner Player_home_player_2  Age_home_player_2  \
# ...

# %%
column_names = list(df.columns)
print(column_names)
# Out:
# ['Unnamed: 0', 'Wk', 'winner', 'home wins', 'away wins', 'home games', 'away games', 'predicted_winner', 'Player_home_player_2', 'Age_home_player_2', 'MP_home_player_2', 'Min_home_player_2', 'Gls_home_player_2', 'Ast_home_player_2', 'PK_home_player_2', 'PKatt_home_player_2', 'CrdY_home_player_2', 'CrdR_home_player_2', 'Starts_home_player_2', 'Player_home_player_3', 'Age_home_player_3', 'MP_home_player_3', 'Min_home_player_3', 'Gls_home_player_3', 'Ast_home_player_3', 'PK_home_player_3', 'PKatt_home_player_3', 'CrdY_home_player_3', 'CrdR_home_player_3', 'Starts_home_player_3', 'Player_home_player_4', 'Age_home_player_4', 'MP_home_player_4', 'Min_home_player_4', 'Gls_home_player_4', 'Ast_home_player_4', 'PK_home_player_4', 'PKatt_home_player_4', 'CrdY_home_player_4', 'CrdR_home_player_4', 'Starts_home_player_4', 'Player_home_player_5', 'Age_home_player_5', 'MP_home_player_5', 'Min_home_player_5', 'Gls_home_player_5', 'Ast_home_player_5', 'PK_home_player_5', 'PKatt_home_player_5', 'CrdY
# ...

# %%
# drop columns starting with Squad

df.drop(columns=[col for col in df.columns if col.startswith('Squad')], inplace=True)

# %%
# drop columns starting with Unnamed or Player

df.drop(columns=[col for col in df.columns if col.startswith('Unnamed:') or col.startswith('Player')], inplace=True)

# %%
# Print the shape of resulting DataFrame
df.shape
# Out:
# (6059, 249)

# %%
# 'winner' is the column name for labels
import random
random.seed(42)
labels = df['winner'].values

# Drop the label column to get features
features = df.drop(columns=['winner']).values

# Instantiate the MinMaxScaler
scaler = MinMaxScaler()

# Fit and transform the features
normalized_features = scaler.fit_transform(features)

# Convert to PyTorch tensors
features_tensor = torch.tensor(normalized_features, dtype=torch.float32)
labels_tensor = torch.tensor(labels, dtype=torch.long)

features_tensor[torch.isnan(features_tensor)] = 0

# %%
from sklearn.model_selection import train_test_split
random.seed(42)
# Split the dataset into training and testing sets
train_features, rem_features, train_labels, rem_labels = train_test_split(features_tensor, labels_tensor, test_size=0.3, random_state=50)

# Further split the training set into training and validation sets
val_features, test_features, val_labels, test_labels = train_test_split(rem_features, rem_labels, test_size=0.6, random_state=50)

train_dataset = TensorDataset(train_features, train_labels)
val_dataset = TensorDataset(val_features, val_labels)
test_dataset = TensorDataset(test_features, test_labels)

# %% [markdown]
# # THE MODELS

# %%
class NeuralNetwork5(nn.Module):
    def __init__(self, input_size, hidden_size1, hidden_size2,hidden_size3,hidden_size4,hidden_size5, num_classes):
        super(NeuralNetwork5, self).__init__()
        self.name = 'NeuralNetwork5'
        self.fc1 = nn.Linear(input_size, hidden_size1)
        self.fc2 = nn.Linear(hidden_size1,hidden_size2)
        self.fc3 = nn.Linear(hidden_size2, hidden_size3)
        self.fc4 = nn.Linear(hidden_size3, hidden_size4)
        self.fc5 = nn.Linear(hidden_size4, hidden_size5)
        self.fc6 = nn.Linear(hidden_size5, num_classes)

    def forward(self, x):
        out = self.fc1(x)
        out = F.relu(out)
        out = self.fc2(out)
        out = F.relu(out)
        out = self.fc3(out)
        out = F.relu(out)
        out = self.fc4(out)
        out = F.relu(out)
        out = self.fc5(out)
        out = F.relu(out)
        out = self.fc6(out)

        return out

# %%
class NeuralNetwork7(nn.Module):
    def __init__(self, input_size, hidden_size1, hidden_size2, hidden_size3, hidden_size4, hidden_size5, hidden_size6, hidden_size7, num_classes):
        super(NeuralNetwork7, self).__init__()
        self.name = 'NeuralNetwork7'
        self.fc1 = nn.Linear(input_size, hidden_size1)
        self.fc2 = nn.Linear(hidden_size1, hidden_size2)
        self.fc3 = nn.Linear(hidden_size2, hidden_size3)
        self.fc4 = nn.Linear(hidden_size3, hidden_size4)
        self.fc5 = nn.Linear(hidden_size4, hidden_size5)
        self.fc6 = nn.Linear(hidden_size5, hidden_size6)
        self.fc7 = nn.Linear(hidden_size6, hidden_size7)
        self.fc8 = nn.Linear(hidden_size7, num_classes)

    def forward(self, x):
        x = nn.functional.relu(self.fc1(x))
        x = nn.functional.relu(self.fc2(x))
        x = nn.functional.relu(self.fc3(x))
        x = nn.functional.relu(self.fc4(x))
        x = nn.functional.relu(self.fc5(x))
        x = nn.functional.relu(self.fc6(x))
        x = nn.functional.relu(self.fc7(x))
        x = self.fc8(x)
        return x

# %%
import torch.nn as nn

class NeuralNetwork9(nn.Module):
    def __init__(self, input_size, hidden_size1, hidden_size2, hidden_size3, hidden_size4, hidden_size5, hidden_size6, hidden_size7, hidden_size8, hidden_size9, num_classes):
        super(NeuralNetwork9, self).__init__()
        self.name = 'NeuralNetwork9'
        self.fc1 = nn.Linear(input_size, hidden_size1)
        self.fc2 = nn.Linear(hidden_size1, hidden_size2)
        self.fc3 = nn.Linear(hidden_size2, hidden_size3)
        self.fc4 = nn.Linear(hidden_size3, hidden_size4)
        self.fc5 = nn.Linear(hidden_size4, hidden_size5)
        self.fc6 = nn.Linear(hidden_size5, hidden_size6)
        self.fc7 = nn.Linear(hidden_size6, hidden_size7)
        self.fc8 = nn.Linear(hidden_size7, hidden_size8)
        self.fc9 = nn.Linear(hidden_size8, hidden_size9)
        self.fc10 = nn.Linear(hidden_size9, num_classes)

    def forward(self, x):
        x = nn.functional.relu(self.fc1(x))
        x = nn.functional.relu(self.fc2(x))
        x = nn.functional.relu(self.fc3(x))
        x = nn.functional.relu(self.fc4(x))
        x = nn.functional.relu(self.fc5(x))
        x = nn.functional.relu(self.fc6(x))
        x = nn.functional.relu(self.fc7(x))
        x = nn.functional.relu(self.fc8(x))
        x = nn.functional.relu(self.fc9(x))
        x = self.fc10(x)
        return x

# %% [markdown]
# # THE TRAIN FUNCTION

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
import os
def train_with_early_stopping(model, train_dataset, val_dataset, batch_size=64, num_epochs=1, print_stat=1, learning_rate=0.05, mm=0, patience=5):
    random.seed(42)
    # Create data loaders for training and validation sets
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=batch_size)

    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=learning_rate, betas=(0.9, 0.999), weight_decay=mm)

    iters, losses, train_acc, val_acc = [], [], [], []

    best_val_acc = 0.0
    counter = 0  # Counter to track the number of epochs without improvement
    best_model_state = None

    for epoch in range(num_epochs):
        curr_loss = 0
        ii = 0
        for imgs, labels in train_loader:
            out = model(imgs)  # Forward pass
            loss = criterion(out, labels)  # Compute loss
            loss.backward()  # Backward pass (compute parameter updates)
            optimizer.step()  # Update parameters
            optimizer.zero_grad()  # Zero the gradients
            curr_loss += loss.item()  # Accumulate loss
            ii += 1

        # Calculate average training loss
        avg_train_loss = curr_loss / ii

        # Calculate training and validation accuracy
        train_accuracy = get_accuracy(model, train_loader)
        val_accuracy = get_accuracy(model, val_loader)

        # Save training and validation metrics
        iters.append(epoch)
        losses.append(avg_train_loss)
        train_acc.append(train_accuracy)
        val_acc.append(val_accuracy)

        # Print training and validation stats
        if print_stat:
            print("Epoch %s: Training Accuracy: %s || Validation Accuracy: %s" % (epoch, train_accuracy, val_accuracy))

        # Check for improvement in validation accuracy
        if val_accuracy > best_val_acc:
            best_val_acc = val_accuracy
            counter = 0
            best_model_state = model.state_dict()
        else:
            counter += 1

        # Check early stopping condition
        if counter >= patience:
            print(f"Stopping early at epoch {epoch} as validation accuracy did not improve for {patience} epochs.")
            break

    # Load the best model state
    if best_model_state:
        model.load_state_dict(best_model_state)

    validation_accuracy = val_acc[-1]
    if validation_accuracy > 0.53:
      # Define the directory to save the model
      save_dir = "/content/drive/MyDrive/APS360_Project/Models"

      # Create the directory if it doesn't exist
      if not os.path.exists(save_dir):
          os.makedirs(save_dir)

      # Define the filename
      model_filename = f"{validation_accuracy}_{learning_rate}_{batch_size}_{model.name}.pth"

      # Save the model
      torch.save(model.state_dict(), os.path.join(save_dir, model_filename))
    # Plot training curve
      plt.title("Training Curve")
      plt.plot(iters, losses, label="Train")
      plt.xlabel("Epochs")
      plt.ylabel("Loss")
      plt.show()

      plt.title("Training Curve")
      plt.plot(iters, train_acc, label="Train")
      plt.plot(iters, val_acc, label="Validation")
      plt.xlabel("Epochs")
      plt.ylabel("Accuracy")
      plt.legend(loc='best')
      plt.show()

      print("Final Training Accuracy: {}".format(train_acc[-1]))
      print("Final Validation Accuracy: {}".format(val_acc[-1]))

    return train_acc[-1], val_acc[-1]

def get_accuracy(model, data_loader):
    model.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for imgs, labels in data_loader:
            outputs = model(imgs)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
    return correct / total

# %% [markdown]
# # THE HYPERPARAMETERS

# %%
random.seed(42)
learning_rates = [random.uniform(0.0001, 0.001) for _ in range(20)]
batch_sizes = [random.randint(1, 128) for _ in range(5)]
hidden_sizes_list = []

# Generate 10 lists
for _ in range(10):
    # Generate a list of 9 random numbers
    random_numbers = [random.randint(3, 90) for _ in range(9)]
    # Sort the list in decreasing order
    random_numbers.sort(reverse=True)
    # Append the sorted list to the random_lists
    hidden_sizes_list.append(random_numbers)

# %%
print(learning_rates)
print(batch_sizes)
for hidden in hidden_sizes_list:
  print(hidden)
# Out:
# [0.0006754841186120954, 0.00012250967970040024, 0.0003475263865322073, 0.0003008896643339405, 0.0007628240927476112, 0.0007090295386806202, 0.0009029616109343609, 0.00017824494936647452, 0.00047972963771674337, 0.0001268174974942633, 0.00029677417732324303, 0.0005548197592930261, 0.00012388237271547726, 0.00027895388561798365, 0.0006848959940015709, 0.000590447332542895, 0.000298396559836627, 0.0006303391154883179, 0.000828487411010044, 0.00010584888371025492]
# [41, 109, 88, 72, 40]
# [80, 51, 48, 47, 46, 30, 16, 15, 14]
# [73, 71, 61, 51, 40, 36, 18, 13, 8]
# [87, 83, 82, 76, 49, 32, 27, 11, 8]
# [84, 61, 51, 49, 40, 38, 32, 15, 13]
# [90, 88, 85, 50, 48, 37, 29, 23, 12]
# [84, 80, 71, 62, 51, 37, 34, 24, 23]
# [90, 84, 74, 44, 43, 32, 31, 10, 7]
# [86, 75, 66, 54, 43, 37, 30, 30, 11]
# [85, 74, 71, 61, 53, 36, 34, 21, 20]
# [77, 77, 68, 57, 54, 49, 36, 31, 20]

# %% [markdown]
# # 5 Hidden Layers, decreasing parameters number

# %% [markdown]
# ## Hidden list 0

# %%
input_size = features_tensor.shape[1]
hidden_sizes = hidden_sizes_list[0]
hidden_size1 = hidden_sizes[0]
hidden_size2 = hidden_sizes[1]
hidden_size3 = hidden_sizes[2]
hidden_size4 = hidden_sizes[3]
hidden_size5 = hidden_sizes[4]
num_classes = 3

for learning_rate in learning_rates:
  print('\nlearning rate: ',learning_rate)
  model = NeuralNetwork5(input_size, hidden_size1, hidden_size2, hidden_size3,hidden_size4, hidden_size5, num_classes)
  train_with_early_stopping(model, val_dataset, train_dataset, batch_size=64, num_epochs=30, print_stat=0, learning_rate=0.00009)
# Out:
# learning rate:  0.0006754841186120954
# Stopping early at epoch 8 as validation accuracy did not improve for 5 epochs.
#
# learning rate:  0.00012250967970040024
# Stopping early at epoch 7 as validation accuracy did not improve for 5 epochs.
#
# learning rate:  0.0003475263865322073
# Stopping early at epoch 10 as validation accuracy did not improve for 5 epochs.
#
# learning rate:  0.0003008896643339405
# Stopping early at epoch 5 as validation accuracy did not improve for 5 epochs.
#
# learning rate:  0.0007628240927476112
# Stopping early at epoch 5 as validation accuracy did not improve for 5 epochs.
#
# learning rate:  0.0007090295386806202
# Stopping early at epoch 6 as validation accuracy did not improve for 5 epochs.
#
# learning rate:  0.0009029616109343609
# Stopping early at epoch 9 as validation accuracy did not improve for 5 epochs.
#
# learning rate:  0.00017824494936647452
# Stopping early at epoch 7 as validation accuracy did not improve for 5 epochs.
#
# ...

# %% [markdown]
# # 5 hidden layers bottleneck architecture

# %% [markdown]
# ## Hidden list 0

# %%
input_size = features_tensor.shape[1]
hidden_sizes = hidden_sizes_list[0]
hidden_size1 = hidden_sizes[4]
hidden_size2 = hidden_sizes[2]
hidden_size3 = hidden_sizes[1]
hidden_size4 = hidden_sizes[2]
hidden_size5 = hidden_sizes[4]


num_classes = 3
for batch_size in batch_sizes:
  print('\nbatch size: ', batch_size)
  for learning_rate in learning_rates:
    print('\nlearning rate: ',learning_rate)
    model = NeuralNetwork5(input_size, hidden_size1, hidden_size2, hidden_size3,hidden_size4, hidden_size5, num_classes)
    train_with_early_stopping(model, val_dataset, train_dataset, batch_size=batch_size, num_epochs=30, print_stat=0, learning_rate=learning_rate)
# Out:
# batch size:  41
#
# learning rate:  0.0006754841186120954
# Stopping early at epoch 5 as validation accuracy did not improve for 5 epochs.
#
# learning rate:  0.00012250967970040024
# Stopping early at epoch 5 as validation accuracy did not improve for 5 epochs.
#
# learning rate:  0.0003475263865322073
# Stopping early at epoch 7 as validation accuracy did not improve for 5 epochs.
#
# learning rate:  0.0003008896643339405
# Stopping early at epoch 5 as validation accuracy did not improve for 5 epochs.
#
# learning rate:  0.0007628240927476112
# Stopping early at epoch 5 as validation accuracy did not improve for 5 epochs.
#
# learning rate:  0.0007090295386806202
# Stopping early at epoch 13 as validation accuracy did not improve for 5 epochs.
#
# learning rate:  0.0009029616109343609
# Stopping early at epoch 18 as validation accuracy did not improve for 5 epochs.
#
# learning rate:  0.00017824494936647452
# ...

# %% [markdown]
# # 7 hidden layers bottleneck architechture

# %% [markdown]
# ## We will be using 41 batch size as it performed best

# %%
input_size = features_tensor.shape[1]
hidden_sizes = hidden_sizes_list[1]
hidden_size1 = hidden_sizes[5]
hidden_size2 = hidden_sizes[4]
hidden_size3 = hidden_sizes[3]
hidden_size4 = hidden_sizes[2]
hidden_size5 = hidden_sizes[3]
hidden_size6 = hidden_sizes[4]
hidden_size7 = hidden_sizes[5]


num_classes = 3

for learning_rate in learning_rates:
  print('\nlearning rate: ',learning_rate)
  model = NeuralNetwork7(input_size, hidden_size1, hidden_size2, hidden_size3,hidden_size4, hidden_size5,
                          hidden_size6, hidden_size7, num_classes)
  train_with_early_stopping(model, val_dataset, train_dataset, batch_size=41, num_epochs=30, print_stat=0, learning_rate=learning_rate)
# Out:
# learning rate:  0.0006754841186120954
# Stopping early at epoch 5 as validation accuracy did not improve for 5 epochs.
#
# learning rate:  0.00012250967970040024
# Stopping early at epoch 5 as validation accuracy did not improve for 5 epochs.
#
# learning rate:  0.0003475263865322073
# Stopping early at epoch 5 as validation accuracy did not improve for 5 epochs.
#
# learning rate:  0.0003008896643339405
# Stopping early at epoch 8 as validation accuracy did not improve for 5 epochs.
#
# learning rate:  0.0007628240927476112
# Stopping early at epoch 6 as validation accuracy did not improve for 5 epochs.
#
# learning rate:  0.0007090295386806202
# Stopping early at epoch 5 as validation accuracy did not improve for 5 epochs.
#
# learning rate:  0.0009029616109343609
# Stopping early at epoch 5 as validation accuracy did not improve for 5 epochs.
#
# learning rate:  0.00017824494936647452
# Stopping early at epoch 5 as validation accuracy did not improve for 5 epochs.
#
# ...

# %% [markdown]
# # Varying the hidden layers

# %%
learning_rate = 0.0006303391154883179
batch_size = 41
input_size = features_tensor.shape[1]
hidden_sizes = hidden_sizes_list[1]
hidden_size1 = hidden_sizes[5]
hidden_size2 = hidden_sizes[4]
hidden_size3 = hidden_sizes[3]
hidden_size4 = hidden_sizes[2]
hidden_size5 = hidden_sizes[3]
hidden_size6 = hidden_sizes[4]
hidden_size7 = hidden_sizes[5]


num_classes = 3

model = NeuralNetwork7(input_size, hidden_size1, hidden_size2, hidden_size3,hidden_size4, hidden_size5,
                        hidden_size6, hidden_size7, num_classes)
train_with_early_stopping(model, val_dataset, train_dataset, batch_size=batch_size, num_epochs=30, print_stat=0, learning_rate=learning_rate
                          ,patience=10, mm=0.0001)
# Out:
# (0.6134800550206327, 0.5140297099740627)

# %%
learning_rate = 0.0006303391154883179
batch_size = 41
input_size = features_tensor.shape[1]
hidden_sizes = hidden_sizes_list[1]
hidden_size1 = hidden_sizes[4]
hidden_size2 = hidden_sizes[3]
hidden_size3 = hidden_sizes[2]
hidden_size4 = hidden_sizes[1]
hidden_size5 = hidden_sizes[2]
hidden_size6 = hidden_sizes[3]
hidden_size7 = hidden_sizes[4]


num_classes = 3

model = NeuralNetwork7(input_size, hidden_size1, hidden_size2, hidden_size3,hidden_size4, hidden_size5,
                        hidden_size6, hidden_size7, num_classes)
train_with_early_stopping(model, val_dataset, train_dataset, batch_size=batch_size, num_epochs=30, print_stat=0, learning_rate=learning_rate
                          ,patience=10, mm=0.0001)
# Out:
# Stopping early at epoch 24 as validation accuracy did not improve for 10 epochs.
# (0.6423658872077029, 0.517330818203254)

# %% [markdown]
# # Decreasing paramters architecture

# %%
learning_rate = 0.0006303391154883179
batch_size = 41
input_size = features_tensor.shape[1]
hidden_sizes = hidden_sizes_list[1]
hidden_size1 = hidden_sizes[0]
hidden_size2 = hidden_sizes[1]
hidden_size3 = hidden_sizes[2]
hidden_size4 = hidden_sizes[3]
hidden_size5 = hidden_sizes[4]
hidden_size6 = hidden_sizes[5]
hidden_size7 = hidden_sizes[6]


num_classes = 3

model = NeuralNetwork7(input_size, hidden_size1, hidden_size2, hidden_size3,hidden_size4, hidden_size5,
                        hidden_size6, hidden_size7, num_classes)
train_with_early_stopping(model, val_dataset, train_dataset, batch_size=batch_size, num_epochs=30, print_stat=0, learning_rate=learning_rate
                          ,patience=10, mm=0.0001)
# Out:
# Stopping early at epoch 21 as validation accuracy did not improve for 10 epochs.
# (0.5873452544704264, 0.5232256543268097)

# %%
learning_rate = 0.0006303391154883179
batch_size = 41
input_size = features_tensor.shape[1]
for hidden_sizes in hidden_sizes_list:
  print('\nhidden_sizes: ',hidden_sizes)
  hidden_size1 = hidden_sizes[0]
  hidden_size2 = hidden_sizes[1]
  hidden_size3 = hidden_sizes[2]
  hidden_size4 = hidden_sizes[3]
  hidden_size5 = hidden_sizes[4]
  hidden_size6 = hidden_sizes[5]
  hidden_size7 = hidden_sizes[6]


  num_classes = 3

  model = NeuralNetwork7(input_size, hidden_size1, hidden_size2, hidden_size3,hidden_size4, hidden_size5,
                          hidden_size6, hidden_size7, num_classes)
  train_with_early_stopping(model, val_dataset, train_dataset, batch_size=batch_size, num_epochs=30, print_stat=0, learning_rate=learning_rate
                            ,patience=10, mm=0.0001)
# Out:
# hidden_sizes:  [80, 51, 48, 47, 46, 30, 16, 15, 14]
#
# hidden_sizes:  [73, 71, 61, 51, 40, 36, 18, 13, 8]
#
# hidden_sizes:  [87, 83, 82, 76, 49, 32, 27, 11, 8]
# Stopping early at epoch 19 as validation accuracy did not improve for 10 epochs.
#
# hidden_sizes:  [84, 61, 51, 49, 40, 38, 32, 15, 13]
# Stopping early at epoch 25 as validation accuracy did not improve for 10 epochs.
#
# hidden_sizes:  [90, 88, 85, 50, 48, 37, 29, 23, 12]
# Stopping early at epoch 17 as validation accuracy did not improve for 10 epochs.
#
# hidden_sizes:  [84, 80, 71, 62, 51, 37, 34, 24, 23]
#
# hidden_sizes:  [90, 84, 74, 44, 43, 32, 31, 10, 7]
#
# hidden_sizes:  [86, 75, 66, 54, 43, 37, 30, 30, 11]
#
# hidden_sizes:  [85, 74, 71, 61, 53, 36, 34, 21, 20]
#
# hidden_sizes:  [77, 77, 68, 57, 54, 49, 36, 31, 20]
# Stopping early at epoch 29 as validation accuracy did not improve for 10 epochs.

# %%
learning_rate = 0.0006303391154883179
batch_size = 41
input_size = features_tensor.shape[1]
for hidden_sizes in hidden_sizes_list:
  print('\nhidden_sizes: ',hidden_sizes)
  hidden_size1 = hidden_sizes[0]
  hidden_size2 = hidden_sizes[1]
  hidden_size3 = hidden_sizes[0]
  hidden_size4 = hidden_sizes[1]
  hidden_size5 = hidden_sizes[2]
  hidden_size6 = hidden_sizes[3]
  hidden_size7 = hidden_sizes[4]


  num_classes = 3

  model = NeuralNetwork7(input_size, hidden_size1, hidden_size2, hidden_size3,hidden_size4, hidden_size5,
                          hidden_size6, hidden_size7, num_classes)
  train_with_early_stopping(model, val_dataset, train_dataset, batch_size=batch_size, num_epochs=30, print_stat=0, learning_rate=learning_rate
                            ,patience=10, mm=0.0001)
# Out:
# hidden_sizes:  [80, 51, 48, 47, 46, 30, 16, 15, 14]
#
# hidden_sizes:  [73, 71, 61, 51, 40, 36, 18, 13, 8]
#
# hidden_sizes:  [87, 83, 82, 76, 49, 32, 27, 11, 8]
# Stopping early at epoch 24 as validation accuracy did not improve for 10 epochs.
#
# hidden_sizes:  [84, 61, 51, 49, 40, 38, 32, 15, 13]
# Stopping early at epoch 20 as validation accuracy did not improve for 10 epochs.
#
# hidden_sizes:  [90, 88, 85, 50, 48, 37, 29, 23, 12]
# Stopping early at epoch 16 as validation accuracy did not improve for 10 epochs.
#
# hidden_sizes:  [84, 80, 71, 62, 51, 37, 34, 24, 23]
# Stopping early at epoch 17 as validation accuracy did not improve for 10 epochs.
#
# hidden_sizes:  [90, 84, 74, 44, 43, 32, 31, 10, 7]
#
# hidden_sizes:  [86, 75, 66, 54, 43, 37, 30, 30, 11]
# Stopping early at epoch 25 as validation accuracy did not improve for 10 epochs.
#
# hidden_sizes:  [85, 74, 71, 61, 53, 36, 34, 21, 20]
# Stopping early at epoch 29 as validation accuracy did not improve for 10 epochs.
#
# ...

# %%
learning_rate = 0.0006303391154883179
batch_size = 41
input_size = features_tensor.shape[1]
for hidden_sizes in hidden_sizes_list:
  print('\nhidden_sizes: ',hidden_sizes)
  hidden_size1 = hidden_sizes[0]
  hidden_size2 = hidden_sizes[1]
  hidden_size3 = hidden_sizes[0]
  hidden_size4 = hidden_sizes[1]
  hidden_size5 = hidden_sizes[2]
  hidden_size6 = hidden_sizes[3]
  hidden_size7 = hidden_sizes[4]


  num_classes = 3

  model = NeuralNetwork7(input_size, hidden_size1, hidden_size2, hidden_size3,hidden_size4, hidden_size5,
                          hidden_size6, hidden_size7, num_classes)
  train_with_early_stopping(model, val_dataset, train_dataset, batch_size=batch_size, num_epochs=40, print_stat=0, learning_rate=learning_rate
                            ,patience=10, mm=0.0001)
# Out:
# hidden_sizes:  [80, 51, 48, 47, 46, 30, 16, 15, 14]
# Stopping early at epoch 19 as validation accuracy did not improve for 10 epochs.
#
# hidden_sizes:  [73, 71, 61, 51, 40, 36, 18, 13, 8]
# Stopping early at epoch 31 as validation accuracy did not improve for 10 epochs.
#
# hidden_sizes:  [87, 83, 82, 76, 49, 32, 27, 11, 8]
# Stopping early at epoch 36 as validation accuracy did not improve for 10 epochs.
#
# hidden_sizes:  [84, 61, 51, 49, 40, 38, 32, 15, 13]
#
# hidden_sizes:  [90, 88, 85, 50, 48, 37, 29, 23, 12]
# Stopping early at epoch 35 as validation accuracy did not improve for 10 epochs.
#
# hidden_sizes:  [84, 80, 71, 62, 51, 37, 34, 24, 23]
# Stopping early at epoch 18 as validation accuracy did not improve for 10 epochs.
#
# hidden_sizes:  [90, 84, 74, 44, 43, 32, 31, 10, 7]
# Stopping early at epoch 17 as validation accuracy did not improve for 10 epochs.
#
# hidden_sizes:  [86, 75, 66, 54, 43, 37, 30, 30, 11]
# ...

# %%
learning_rate = 0.0006303391154883179
batch_size = 16
input_size = features_tensor.shape[1]
for hidden_sizes in hidden_sizes_list:
  print('\nhidden_sizes: ',hidden_sizes)
  hidden_size1 = hidden_sizes[0]
  hidden_size2 = hidden_sizes[1]
  hidden_size3 = hidden_sizes[0]
  hidden_size4 = hidden_sizes[1]
  hidden_size5 = hidden_sizes[2]
  hidden_size6 = hidden_sizes[3]
  hidden_size7 = hidden_sizes[4]


  num_classes = 3

  model = NeuralNetwork7(input_size, hidden_size1, hidden_size2, hidden_size3,hidden_size4, hidden_size5,
                          hidden_size6, hidden_size7, num_classes)
  train_with_early_stopping(model, val_dataset, train_dataset, batch_size=batch_size, num_epochs=30, print_stat=0, learning_rate=learning_rate
                            ,patience=10, mm=0.0001)
# Out:
# hidden_sizes:  [80, 51, 48, 47, 46, 30, 16, 15, 14]
# Stopping early at epoch 26 as validation accuracy did not improve for 10 epochs.
#
# hidden_sizes:  [73, 71, 61, 51, 40, 36, 18, 13, 8]
# Stopping early at epoch 25 as validation accuracy did not improve for 10 epochs.
#
# hidden_sizes:  [87, 83, 82, 76, 49, 32, 27, 11, 8]
# Stopping early at epoch 24 as validation accuracy did not improve for 10 epochs.
#
# hidden_sizes:  [84, 61, 51, 49, 40, 38, 32, 15, 13]
# Stopping early at epoch 23 as validation accuracy did not improve for 10 epochs.
#
# hidden_sizes:  [90, 88, 85, 50, 48, 37, 29, 23, 12]
# Stopping early at epoch 21 as validation accuracy did not improve for 10 epochs.
#
# hidden_sizes:  [84, 80, 71, 62, 51, 37, 34, 24, 23]
# Stopping early at epoch 23 as validation accuracy did not improve for 10 epochs.
#
# hidden_sizes:  [90, 84, 74, 44, 43, 32, 31, 10, 7]
# Stopping early at epoch 19 as validation accuracy did not improve for 10 epochs.
#
# ...

# %% [markdown]
# # EXAMPLE USAGE

# %%
model.eval()

# Sample input data (change this according to your data)
input_data = torch.randn(1, features_tensor.shape[1])  # Assuming 1 sample with 41 features

# Forward pass
with torch.no_grad():
    output = model(input_data)

# Get the predicted class (assuming output is logits)
_, predicted = torch.max(output, 1)
output = torch.sigmoid(output)
print("Predicted class: ", predicted.item())
print("percentages class: ", output)
# Out:
# Predicted class:  0
# percentages class:  tensor([[0.8829, 0.1939, 0.2912]])

# %%
import torch.nn as nn

class NeuralNetwork20(nn.Module):
    def __init__(self, input_size, hidden_sizes, num_classes):
        super(NeuralNetwork20, self).__init__()
        self.name = 'NeuralNetwork20'
        self.hidden_layers = nn.ModuleList()

        # Add the input layer
        self.hidden_layers.append(nn.Linear(input_size, hidden_sizes[0]))

        # Add hidden layers
        for i in range(1, len(hidden_sizes)):
            self.hidden_layers.append(nn.Linear(hidden_sizes[i-1], hidden_sizes[i]))

        # Output layer
        self.output_layer = nn.Linear(hidden_sizes[-1], num_classes)

    def forward(self, x):
        # Pass through hidden layers
        for layer in self.hidden_layers:
            x = nn.functional.relu(layer(x))
        # Pass through output layer
        x = self.output_layer(x)
        return x

# %%
# Define input size, hidden sizes, and output size
learning_rate = 0.0007090295386806202
batch_size = 41
input_size = features_tensor.shape[1]
import random

# Randomly generate three lists of hidden layer sizes
hidden_sizes_1 = [random.randint(3, 300) for _ in range(20)]  # 20 layers
hidden_sizes_2 = [random.randint(3, 300) for _ in range(20)]  # 20 layers
hidden_sizes_3 = [random.randint(3, 300) for _ in range(20)]  # 20 layers


num_classes = 3

# Initialize the model
model = NeuralNetwork20(input_size, hidden_sizes_1, num_classes)
train_with_early_stopping(model, val_dataset, train_dataset, batch_size=batch_size, num_epochs=30, print_stat=0, learning_rate=learning_rate
                          ,patience=10, mm=0.0001)
# Out:
# Stopping early at epoch 10 as validation accuracy did not improve for 10 epochs.
# (0.4484181568088033, 0.4557887290733318)

# %%
# Define input size, hidden sizes, and output size
learning_rate = 0.0007090295386806202
batch_size = 41
input_size = features_tensor.shape[1]
import random

# Randomly generate three lists of hidden layer sizes
hidden_sizes_1 = [random.randint(3, 300) for _ in range(20)]  # 20 layers
hidden_sizes_2 = [random.randint(3, 300) for _ in range(20)]  # 20 layers
hidden_sizes_3 = [random.randint(3, 300) for _ in range(20)]  # 20 layers


num_classes = 3

# Initialize the model
model = NeuralNetwork20(input_size, hidden_sizes_2, num_classes)
train_with_early_stopping(model, val_dataset, train_dataset, batch_size=batch_size, num_epochs=30, print_stat=0, learning_rate=learning_rate
                          ,patience=10, mm=0.0001)
# Out:
# Stopping early at epoch 10 as validation accuracy did not improve for 10 epochs.
# (0.4484181568088033, 0.4557887290733318)

# %%
# Define input size, hidden sizes, and output size
learning_rate = 0.0007090295386806202
batch_size = 41
input_size = features_tensor.shape[1]
import random

# Randomly generate three lists of hidden layer sizes
hidden_sizes_1 = [random.randint(3, 300) for _ in range(20)]  # 20 layers
hidden_sizes_2 = [random.randint(3, 300) for _ in range(20)]  # 20 layers
hidden_sizes_3 = [random.randint(3, 300) for _ in range(20)]  # 20 layers


num_classes = 3

# Initialize the model
model = NeuralNetwork20(input_size, hidden_sizes_3, num_classes)
train_with_early_stopping(model, val_dataset, train_dataset, batch_size=batch_size, num_epochs=30, print_stat=0, learning_rate=learning_rate
                          ,patience=10, mm=0.0001)
# Out:
# Stopping early at epoch 10 as validation accuracy did not improve for 10 epochs.
# (0.4484181568088033, 0.4557887290733318)

# %%
# Define input size, hidden sizes, and output size
learning_rate = 0.0007090295386806202
batch_size = 20
input_size = features_tensor.shape[1]

num_classes = 3

# Initialize the model
model = NeuralNetwork20(input_size, hidden_sizes_3, num_classes)
train_with_early_stopping(model, val_dataset, train_dataset, batch_size=batch_size, num_epochs=30, print_stat=0, learning_rate=learning_rate
                          ,patience=10, mm=0.0001)
# Out:
# Stopping early at epoch 10 as validation accuracy did not improve for 10 epochs.
# (0.4484181568088033, 0.4557887290733318)
